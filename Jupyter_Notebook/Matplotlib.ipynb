# %%
#%matplotlib inline
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np

# %%
 # @hidden_cell
    
x = [-1, 5]
y = [-2, 8]
plt.grid(True)
plt.scatter(x, y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9833333333333">

# %%
curve = [np.arange(-3, 2*np.pi, 0.01), np.sin(np.arange(-3, 2*np.pi, 0.01))]
curve2 = [[np.arange(-3, 2*np.pi, 0.01), np.sin(np.arange(-3, 2*np.pi, 0.01))], [[-3, 8], [-1, 0.5]]]
curve3 = [
          [
           [-3.1,-4.2,5],# Curve1 X
           [-5.3,-6.6,7] # Curve1 Y
          ],
          [
            [4,5,6],     # Curve2 X
            [4, 5, 6]    # Curve2 Y
          ]
         ]

# %%
def displayFigure(data, xlim=[0,0], ylim=[0,0], tick=[0,0], title=""):
    def findDepth(orgList):
        l = orgList.copy()
        cpt = 0

        while isinstance(l, (list, np.ndarray)):
            l = l[0]
            cpt += 1
        return cpt


    fig, ax = plt.subplots()
    ax.set_title(title)
    
    plt.grid(True, linestyle=':')
    
    if xlim != [0,0]:
        ax.set_xlim(xlim[0], xlim[1])
        ax.set_xticks(np.arange(xlim[0], xlim[1], tick[0]))
    
    if ylim != [0,0]:      
        ax.set_ylim(ylim[0], ylim[1])
        ax.set_yticks(np.arange(ylim[0], ylim[1], tick[1]))
    
    ax.tick_params(which='major', direction='inout', length=5, width=2, colors='k')
    ax.tick_params(which='minor', direction='out', length=3, width=1, colors='k')
    
    ax.spines['bottom'].set_position(('data', 0))
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_position(('data', 0))
    
    nbPlot = findDepth(data) - 1
    if nbPlot == 1:
        ax.plot(data[0], data[1])
    elif nbPlot >= 2:
        for p in data:
            #ax.scatter(p[0], p[1])
            ax.plot(p[0], p[1])
        
    
    plt.show()
    
    return None

# %%
displayFigure(curve2, xlim=[-3, 7], tick=[1, 0.25], title='Curve')
# Out:
# <img src="data:image/png;base64,..." width="639.9833333333333">

# %% [markdown]
# Some Markdown text with <span style="text-decoration:underline;color:blue">some *blue* text</span>.

# %% [markdown]
# # Mathe

# %% [markdown]
# \begin{equation*}
# \left( \sum_{k=1}^n a_k b_k \right)^2 \leq \left( \sum_{k=1}^n a_k^2 \right) \left( \sum_{k=1}^n b_k^2 \right)
# \end{equation*}

# %% [markdown]
# \begin{equation*}
# \mathbf{V}_1 \times \mathbf{V}_2 =  \begin{vmatrix}
# \mathbf{i} & \mathbf{j} & \mathbf{k} \\
# \frac{\partial X}{\partial u} &  \frac{\partial Y}{\partial u} & 0 \\
# \frac{\partial X}{\partial v} &  \frac{\partial Y}{\partial v} & 0
# \end{vmatrix}
# \end{equation*}

# %% [markdown]
# \begin{equation*}
# 1 +  \frac{q^2}{(1-q)}+\frac{q^6}{(1-q)(1-q^2)}+\cdots =
# \prod_{j=0}^{\infty}\frac{1}{(1-q^{5j+2})(1-q^{5j+3})},
# \quad\quad \text{for $|q|<1$}.
# \end{equation*}

# %% [markdown]
# Equation $y = A.x + B$ to solve.

# %% [markdown]
# # Links
#
# - [Example Matplotlib](https://matplotlib.org/gallery/index.html)
# - [Anaconda](https://www.anaconda.com/)

# %%
import pandas as pd

t = [{'Product':'Apple', 'Price':3}, {'Product': 'Cherry', 'Price':5}]

# %%
df = pd.DataFrame(t)

# %%
df
# Out:
#   Product  Price
# 0   Apple      3
# 1  Cherry      5
